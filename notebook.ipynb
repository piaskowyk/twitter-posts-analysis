# %%
import psycopg2
import psycopg2.extras
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
from matplotlib.pyplot import figure

# %%
connection = psycopg2.connect(
    database="postgres",
    user="postgres",
    password="password",
    host="127.0.0.1",
    port="5432"
)
db = connection.cursor(cursor_factory=psycopg2.extras.RealDictCursor)

# %%
def getAll(query):
    db.execute(query)
    return db.fetchall()

# %%
result = getAll("SELECT * FROM tweet WHERE fetched_comments is NULL and type = 1")
result
# Out:
# ),
#               ('tags',
#                'Chopper4,BlackLivesMatterDC,BreakingNews,GeorgeFloydProtests,protests2020,BREAKING'),
#               ('user_id', 246571873),
#               ('created_at', datetime.datetime(2020, 6, 6, 22, 8, 12)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 0.93),
#               ('sentiment_pos', 0.07),
#               ('sentiment_compound', 0.2716),
#               ('retweet_count', 2108),
#               ('favorite_count', 4967),
#               ('reply_count', 184),
#               ('quote_count', 277),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', True),
#               ('fetched_quotes', None)]),
#  RealDictRow([('id', 1269418338872111106),
#               ('content',
#                'Now playing : 🎶\n\n“ Covid 😷 “\n\nBy :  \n\nhttps://t.co/InQmoTJokB https://t.co/0cH2GOd3sK'),
#               ('tags', None),
# ...

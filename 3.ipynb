# %%
import psycopg2
import psycopg2.extras
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
from matplotlib.pyplot import figure

# %%
connection = psycopg2.connect(
    database="root",
    user="root",
    password="password",
    host="127.0.0.1",
    port="5432"
)
db = connection.cursor(cursor_factory=psycopg2.extras.RealDictCursor)

# %%
def getAll(query):
    db.execute(query)
    return db.fetchall()

# %%
result = getAll("select * from public.tweet where fetched_comments is null and type = 1;")
result
# Out:
# [RealDictRow([('id', 1321964924650852354),
#               ('content', 'The Biden/Putin  Covid plan'),
#               ('tags', None),
#               ('user_id', 430257546),
#               ('created_at', datetime.datetime(2020, 10, 29, 23, 59, 33)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', None)]),
#  RealDictRow([('id', 1338634799737663492),
#               ('content', 'Eh covid'),
#               ('tags', None),
#               ('user_id', 1126287896837857280),
#               ('created_at', datetime.datetime(2020, 12, 14, 23, 59, 41)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', None)]),
#  RealDictRow([('id', 1381758879781040130),
#               ('content', 'Covid é chatão'),
#               ('tags', None),
#               ('user_id', 952544908975501312),
#               ('created_at', datetime.datetime(2021, 4, 12, 23, 59, 23)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 1),
#               ('reply_count', 1),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', None)]),
#  RealDictRow([('id', 1350593526082531334),
#               ('content', 'Covid 19 ruined everything.'),
#               ('tags', None),
#               ('user_id', 1729114026),
#               ('created_at', datetime.datetime(2021, 1, 16, 23, 59, 24)),
#               ('sentiment_neg', 0.508),
#               ('sentiment_neu', 0.492),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.4767),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', None)]),
#  RealDictRow([('id', 1359290819648360451),
#               ('content', 'Roots Radio - COVID-19FLB'),
#               ('tags', None),
#               ('user_id', 1027422272),
#               ('created_at', datetime.datetime(2021, 2, 9, 23, 59, 20)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', None)]),
#  RealDictRow([('id', 1317616128831651840),
#               ('content', 'Them boys said fuck Covid 😂'),
#               ('tags', None),
#               ('user_id', 567826440),
#               ('created_at', datetime.datetime(2020, 10, 17, 23, 58, 59)),
#               ('sentiment_neg', 0.467),
#               ('sentiment_neu', 0.533),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.5423),
#               ('retweet_count', 1),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', None)]),
#  RealDictRow([('id', 1309643581771198464),
#               ('content', 'Insh ⛔covid'),
#               ('tags', None),
#               ('user_id', 1152622368914849792),
#               ('created_at', datetime.datetime(2020, 9, 25, 23, 58, 56)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 1),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', None)]),
#  RealDictRow([('id', 1242602048954269698),
#               ('content',
#                'Incrível como o Bolsonaro n pega covid filha da puta'),
#               ('tags', None),
#               ('user_id', 1414161344),
#               ('created_at', datetime.datetime(2020, 3, 24, 23, 59, 49)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 2),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1381034168818270210),
#               ('content', 'Dios quiera y se muera de covid 79'),
#               ('tags', None),
#               ('user_id', 909316478217998337),
#               ('created_at', datetime.datetime(2021, 4, 10, 23, 59, 38)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1261446177058258944),
#               ('content', '84 495 CONTAGIADOS POR COVID-19 😨😰'),
#               ('tags', None),
#               ('user_id', 610082506),
#               ('created_at', datetime.datetime(2020, 5, 15, 23, 59, 39)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1294413667581272071),
#               ('content',
#                'Ni que hubiera llegado la vacuna. https://t.co/36TuDbF23v'),
#               ('tags', None),
#               ('user_id', 75852361),
#               ('created_at', datetime.datetime(2020, 8, 14, 23, 20, 42)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 252),
#               ('favorite_count', 1577),
#               ('reply_count', 329),
#               ('quote_count', 88),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1330662270616150029),
#               ('content',
#                'Vaccin anti Covid le délire continue\n\nhttps://t.co/ttIh0RSPLs'),
#               ('tags', None),
#               ('user_id', 266841366),
#               ('created_at', datetime.datetime(2020, 11, 22, 23, 59, 42)),
#               ('sentiment_neg', 0.277),
#               ('sentiment_neu', 0.723),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.3182),
#               ('retweet_count', 1),
#               ('favorite_count', 1),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', None)]),
#  RealDictRow([('id', 1345520172887470081),
#               ('content',
#                '  Look at the USA to see COVID done right! 🤦🏻\u200d♀️'),
#               ('tags', None),
#               ('user_id', 461365220),
#               ('created_at', datetime.datetime(2021, 1, 2, 23, 59, 42)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', None)]),
#  RealDictRow([('id', 1316880273242542082),
#               ('content',
#                "Who's stopping this offense...?\n\n#ChiefsKingdom https://t.co/3dI8LW6oqM"),
#               ('tags', 'ChiefsKingdom'),
#               ('user_id', 903385494909792257),
#               ('created_at', datetime.datetime(2020, 10, 15, 23, 14, 58)),
#               ('sentiment_neg', 0.242),
#               ('sentiment_neu', 0.758),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.1531),
#               ('retweet_count', 233),
#               ('favorite_count', 1748),
#               ('reply_count', 241),
#               ('quote_count', 216),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1316891475335139328),
#               ('content', 'ME MATO POR EL COVID-19 VOY A MORIR FALLECER'),
#               ('tags', None),
#               ('user_id', 1257185642741739522),
#               ('created_at', datetime.datetime(2020, 10, 15, 23, 59, 29)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1316891459480621057),
#               ('content', 'COVID can’t even stop these niggas man...'),
#               ('tags', None),
#               ('user_id', 309587793),
#               ('created_at', datetime.datetime(2020, 10, 15, 23, 59, 25)),
#               ('sentiment_neg', 0.479),
#               ('sentiment_neu', 0.521),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.5574),
#               ('retweet_count', 0),
#               ('favorite_count', 2),
#               ('reply_count', 2),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1316891463641231361),
#               ('content', 'Maybe she has Covid and no one else knows yet?'),
#               ('tags', None),
#               ('user_id', 984188065),
#               ('created_at', datetime.datetime(2020, 10, 15, 23, 59, 26)),
#               ('sentiment_neg', 0.196),
#               ('sentiment_neu', 0.804),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.296),
#               ('retweet_count', 0),
#               ('favorite_count', 1),
#               ('reply_count', 1),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1316891460252405761),
#               ('content',
#                'Sen. Kamala Harris Cancels Travel Plans After Staffer Gets COVID-19 https://t.co/zw6MMsty7n via '),
#               ('tags', None),
#               ('user_id', 144325625),
#               ('created_at', datetime.datetime(2020, 10, 15, 23, 59, 25)),
#               ('sentiment_neg', 0.147),
#               ('sentiment_neu', 0.853),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.2263),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1316891472382263297),
#               ('content',
#                'Due to the #COVID pandemic, 54 million people may face hunger in the US during 2020 — including more than 18 million children.  &amp; , we need to #InvestInKids by making public investments in our nation’s safety net programs to protect our kids. #WeCareDebate'),
#               ('tags', 'COVID,InvestInKids,WeCareDebate'),
#               ('user_id', 27649069),
#               ('created_at', datetime.datetime(2020, 10, 15, 23, 59, 28)),
#               ('sentiment_neg', 0.043),
#               ('sentiment_neu', 0.841),
#               ('sentiment_pos', 0.116),
#               ('sentiment_compound', 0.5267),
#               ('retweet_count', 5),
#               ('favorite_count', 5),
#               ('reply_count', 2),
#               ('quote_count', 1),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1320153016327114755),
#               ('content',
#                'US election roundup: Trump votes in Florida, Biden pledges free Covid vaccine &amp;\xa0more https://t.co/AzZ2aMOqfi'),
#               ('tags', None),
#               ('user_id', 1272575329467392001),
#               ('created_at', datetime.datetime(2020, 10, 24, 23, 59, 41)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 0.809),
#               ('sentiment_pos', 0.191),
#               ('sentiment_compound', 0.5106),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1316891466187329537),
#               ('content', 'duvido nada q já peguei covid e fiquei boa'),
#               ('tags', None),
#               ('user_id', 1006748503245312000),
#               ('created_at', datetime.datetime(2020, 10, 15, 23, 59, 26)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 3),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1316891461628186624),
#               ('content',
#                "People who most ferociously defy the dangers of COVID are usually the same that don't believe in evolution.\nIt's fitting then, that they are also the best candidates to display how natural selection works...\n#evolution #Atheism #DarwinAwards"),
#               ('tags', 'evolution,Atheism,DarwinAwards'),
#               ('user_id', 57733861),
#               ('created_at', datetime.datetime(2020, 10, 15, 23, 59, 25)),
#               ('sentiment_neg', 0.123),
#               ('sentiment_neu', 0.729),
#               ('sentiment_pos', 0.148),
#               ('sentiment_compound', 0.2748),
#               ('retweet_count', 1),
#               ('favorite_count', 4),
#               ('reply_count', 1),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1316891462672367617),
#               ('content',
#                'Easing of COVID-19 restrictions on gatherings in Queensland homes has been brought forward. #covid19 #7NEWS https://t.co/lGvXJh8jRl'),
#               ('tags', 'covid19,7NEWS'),
#               ('user_id', 3312051122),
#               ('created_at', datetime.datetime(2020, 10, 15, 23, 59, 26)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 0.882),
#               ('sentiment_pos', 0.118),
#               ('sentiment_compound', 0.25),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 1),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1316891466447392770),
#               ('content',
#                '#Atentos 👉 Para hoy se reportan 170 nuevos casos de #COVID__19 en #Boyacá\n\nEn Colombia 6.823 casos y 151 fallecidos.\n\nMás detalles 👇 https://t.co/ySK8aJq66F'),
#               ('tags', 'Atentos,COVID__19,Boyacá'),
#               ('user_id', 931502022620340224),
#               ('created_at', datetime.datetime(2020, 10, 15, 23, 59, 26)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1316891455542169601),
#               ('content',
#                'Spin class linked to 72 COVID cases. How were so many infected?  https://t.co/OyTBv2SqMx'),
#               ('tags', None),
#               ('user_id', 625267623),
#               ('created_at', datetime.datetime(2020, 10, 15, 23, 59, 24)),
#               ('sentiment_neg', 0.225),
#               ('sentiment_neu', 0.775),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.539),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978690643546112),
#               ('content',
#                'Han vencido al COVID-19, 576 pacientes del Hospital Civil de #Morelia https://t.co/xhEOmdyL93'),
#               ('tags', 'Morelia'),
#               ('user_id', 3476277794),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 41)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978682317656065),
#               ('content',
#                'Pollution may increase virus transmissibility making people more vulnerable to COVID-19, say\xa0experts https://t.co/knNavfvexL'),
#               ('tags', None),
#               ('user_id', 1293831366711353344),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 39)),
#               ('sentiment_neg', 0.133),
#               ('sentiment_neu', 0.728),
#               ('sentiment_pos', 0.139),
#               ('sentiment_compound', 0.0276),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978687728439299),
#               ('content',
#                'Brasil registra 4.650.030 pacientes recuperados da\xa0Covid-19 https://t.co/aXJxiKIZjs'),
#               ('tags', None),
#               ('user_id', 893835554999218176),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 40)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978690530193409),
#               ('content',
#                'Remember is right because in the era of covid, we no longer do it'),
#               ('tags', None),
#               ('user_id', 1429407367),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 41)),
#               ('sentiment_neg', 0.145),
#               ('sentiment_neu', 0.855),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.296),
#               ('retweet_count', 2),
#               ('favorite_count', 4),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978691868176384),
#               ('content', 'Covid my ass'),
#               ('tags', None),
#               ('user_id', 342297988),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 41)),
#               ('sentiment_neg', 0.636),
#               ('sentiment_neu', 0.364),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.5423),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978670678552576),
#               ('content',
#                'Por covid-19, bolivianos votarán por terminal de cédula en dos turnos durante el día https://t.co/e1XA4U0INZ'),
#               ('tags', None),
#               ('user_id', 76931020),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 36)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 4),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978681554440192),
#               ('content',
#                'La Covid fait craquer nos maillons faibles\nhttps://t.co/x2QdVgTEiS\n\nLa Covid a mis en lumière que notre système de santé est trop lourd à gérer, que les soins prodigués aux aînés ont été négligés et que nos ressources sont nettement insuffisantes.\n\nPhoto: Cybrain et Adobe Stock'),
#               ('tags', None),
#               ('user_id', 79910690),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 39)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978681327845376),
#               ('content',
#                "The child infected with COVID-19 is a boy in one of the hospital's oncology wards. #9News\nhttps://t.co/xo8jSnGbwb"),
#               ('tags', '9News'),
#               ('user_id', 183036128),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 39)),
#               ('sentiment_neg', 0.176),
#               ('sentiment_neu', 0.824),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.4939),
#               ('retweet_count', 2),
#               ('favorite_count', 2),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978680921030657),
#               ('content',
#                'Não tem mais COVID-19 em Manaus. Só pode. Porque o Parque Mirage próximo da ALEAM este lotado !!! Fiscalização cadê você ? #manaus #covid19 #coronavirus #semfiscalizacao'),
#               ('tags', 'manaus,covid19,coronavirus,semfiscalizacao'),
#               ('user_id', 27684840),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 39)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 1),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978696830144515),
#               ('content',
#                'Eu tô mal, aí eu começo a pensar q eu tô com covid'),
#               ('tags', None),
#               ('user_id', 1018897921050365952),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 42)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978693105483776),
#               ('content',
#                'Covid-19 is really a syndemic — and that shows us how to fight it  https://t.co/MlllE2u75Y'),
#               ('tags', None),
#               ('user_id', 933829699679252481),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 41)),
#               ('sentiment_neg', 0.178),
#               ('sentiment_neu', 0.822),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.3818),
#               ('retweet_count', 2),
#               ('favorite_count', 4),
#               ('reply_count', 0),
#               ('quote_count', 1),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978695055888385),
#               ('content',
#                "Coronavirus latest: Japan Inc hires fewer graduates-to-be.\n\nRead the latest news on COVID-19 at Nikkei Asia's free blog:\nhttps://t.co/uOw1oJtjJp"),
#               ('tags', None),
#               ('user_id', 436429668),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 42)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 0.845),
#               ('sentiment_pos', 0.155),
#               ('sentiment_compound', 0.5106),
#               ('retweet_count', 5),
#               ('favorite_count', 3),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978667591421952),
#               ('content',
#                'Bhabinkamtibmas Desa Martasari BRIPKA ARI MUSTOFA Melaksanakan giat Patroli malam sekaligus Sambang di warga binaannya untuk menghimbau agar selalu mamatuhi Protokoler Kesehatan dalam masa Pandemi Covid 19. (Sabtu,17/10/2020) https://t.co/2APh6P0NmM'),
#               ('tags', None),
#               ('user_id', 1293915837301010437),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 35)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978687933943808),
#               ('content',
#                'Se confirmaron 30 casos nuevos de COVID-19 y hay 375 personas cursando la enfermedad https://t.co/eX0JXxstyL'),
#               ('tags', None),
#               ('user_id', 31459537),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 40)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 1),
#               ('favorite_count', 3),
#               ('reply_count', 0),
#               ('quote_count', 1),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317930833949433861),
#               ('content',
#                'Only real ones remember this https://t.co/n4HcxPwwC8'),
#               ('tags', None),
#               ('user_id', 946641151284711424),
#               ('created_at', datetime.datetime(2020, 10, 18, 20, 49, 31)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 16263),
#               ('favorite_count', 70362),
#               ('reply_count', 554),
#               ('quote_count', 7939),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317972059624939520),
#               ('content',
#                'Tom Brady sprinted to shake Aaron Rodgers hand, but let Nick Foles beat him and he can’t get to the Locker Room faster!'),
#               ('tags', None),
#               ('user_id', 239103376),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 33, 20)),
#               ('sentiment_neg', 0.055),
#               ('sentiment_neu', 0.849),
#               ('sentiment_pos', 0.097),
#               ('sentiment_compound', 0.2598),
#               ('retweet_count', 3390),
#               ('favorite_count', 30579),
#               ('reply_count', 737),
#               ('quote_count', 453),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978693638213634),
#               ('content',
#                '52 year old gamer! curious? :) Covid day 6 !charity !giveaway !help Best sub alert on Twitch!!  https://t.co/0Ze1cDbDWm'),
#               ('tags', None),
#               ('user_id', 946027733028687879),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 42)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 0.375),
#               ('sentiment_pos', 0.625),
#               ('sentiment_compound', 0.9543),
#               ('retweet_count', 3),
#               ('favorite_count', 4),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1317978670515060737),
#               ('content',
#                'Covid delayed a wedding, upended jobs and took a loved one — all in one Nevada family #COVID19 https://t.co/8vArouvNox via '),
#               ('tags', 'COVID19'),
#               ('user_id', 174906176),
#               ('created_at', datetime.datetime(2020, 10, 18, 23, 59, 36)),
#               ('sentiment_neg', 0.091),
#               ('sentiment_neu', 0.721),
#               ('sentiment_pos', 0.188),
#               ('sentiment_compound', 0.4588),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065872590274561),
#               ('content',
#                'covid vent. my mom held a family get together over the weekend for the birthdays of 3 old people. tons of susceptible people there. no masks. i was against the idea from the get-go but she pressured me into sitting at the dinner and now my cousin tested positive after i sat-'),
#               ('tags', None),
#               ('user_id', 780105856675221505),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 45)),
#               ('sentiment_neg', 0.073),
#               ('sentiment_neu', 0.836),
#               ('sentiment_pos', 0.091),
#               ('sentiment_compound', 0.4497),
#               ('retweet_count', 0),
#               ('favorite_count', 1),
#               ('reply_count', 1),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065883201970176),
#               ('content',
#                'Hoy se terminó el aislamiento de mi hermana y de Hernan estaban los dos con Covid y encima terminaron el aislamiento el mismo día😂🤦🏻\u200d♀️'),
#               ('tags', None),
#               ('user_id', 2450238236),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 48)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065873949298689),
#               ('content',
#                'Dou me está doliendo todo el puto cuerpo, no sé si es gripa, covid, ser jugador para siempre de división 7 o algo pero me está doliendo como nunca a https://t.co/Rz87WXpoCK'),
#               ('tags', None),
#               ('user_id', 2865908701),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 46)),
#               ('sentiment_neg', 0.075),
#               ('sentiment_neu', 0.925),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.296),
#               ('retweet_count', 0),
#               ('favorite_count', 2),
#               ('reply_count', 2),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065880664379395),
#               ('content', 'Covid negative for the 4th time'),
#               ('tags', None),
#               ('user_id', 33807016),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 47)),
#               ('sentiment_neg', 0.425),
#               ('sentiment_neu', 0.575),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.5719),
#               ('retweet_count', 0),
#               ('favorite_count', 4),
#               ('reply_count', 1),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065879124979712),
#               ('content',
#                '🖋 Sign “COVID-19 relief” and I’ll deliver a copy to your officials: https://t.co/StFCWk896P\n\n📨 No. 1 is from Judith to  and  #KS03 #KSpolitics #KSpol #KSpoli #ProtectOurCare https://t.co/2AwbgjmuRs'),
#               ('tags', 'KS03,KSpolitics,KSpol,KSpoli,ProtectOurCare'),
#               ('user_id', 938533034659168256),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 47)),
#               ('sentiment_neg', 0.091),
#               ('sentiment_neu', 0.909),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.296),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065884267319303),
#               ('content',
#                'Newly released reports show White House saw Covid crisis worsening as Trump downplayed https://t.co/g1oInLNiE2'),
#               ('tags', None),
#               ('user_id', 26160373),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 48)),
#               ('sentiment_neg', 0.372),
#               ('sentiment_neu', 0.628),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.7964),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065878902788097),
#               ('content',
#                'Taxa de ocupação de UTI Covid-19 cai para 39,1% na região de Franca. Leia mais https://t.co/DWM5lNRLqI https://t.co/AeoPmKUjTO'),
#               ('tags', None),
#               ('user_id', 1154163070253641735),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 47)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319064519755231232),
#               ('content',
#                '987 new #COVID19 cases in Idaho today and **11 deaths**. 😢'),
#               ('tags', 'COVID19'),
#               ('user_id', 760492141839736833),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 54, 23)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 12),
#               ('favorite_count', 35),
#               ('reply_count', 10),
#               ('quote_count', 3),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065878651023360),
#               ('content',
#                'CDC redefines COVID-19 close contact, possibly leading to contact tracing in more cases - KTLA Los Angeles https://t.co/ewARPEfDfn'),
#               ('tags', None),
#               ('user_id', 342972141),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 47)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065879058022400),
#               ('content',
#                'Nicole tested negative for COVID and said her immune system was Built by Bama🤣'),
#               ('tags', None),
#               ('user_id', 607814694),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 47)),
#               ('sentiment_neg', 0.207),
#               ('sentiment_neu', 0.67),
#               ('sentiment_pos', 0.123),
#               ('sentiment_compound', -0.3612),
#               ('retweet_count', 0),
#               ('favorite_count', 1),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065888331649024),
#               ('content',
#                'Voting by mail is the safest method for minimizing the risk of COVID-19. For those looking to vote in-person, it is safe but people need to be careful, That means practicing good hand hygiene, wearing masks, maintaining physical distances of at least six feet from others.'),
#               ('tags', None),
#               ('user_id', 47799548),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 49)),
#               ('sentiment_neg', 0.028),
#               ('sentiment_neu', 0.722),
#               ('sentiment_pos', 0.25),
#               ('sentiment_compound', 0.9062),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065873345282049),
#               ('content',
#                '¿ A Nayicito se le fue el Internet o ya anda devolviendo lo robado ? ¿ Ya salió llorando ? ¿ Ya despotricó contra la  ? ¿ O ya dió positivo a #Covid_19 ?\n\n  '),
#               ('tags', 'Covid_19'),
#               ('user_id', 1147294408829747200),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 45)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 16),
#               ('favorite_count', 51),
#               ('reply_count', 7),
#               ('quote_count', 1),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065879183839233),
#               ('content',
#                '🔴 LIVE PODCAST: The New Spot  (LIVE) on  #atl #bx #cali #covid_19 #drill #florida #gangsta_gangsta #hiphop #music #newyork #podcast #rnb #rock #socialdistancing #takeout #worldwide https://t.co/aoBTfu5fcJ'),
#               ('tags',
#                'atl,bx,cali,covid_19,drill,florida,gangsta_gangsta,hiphop,music,newyork,podcast,rnb,rock,socialdistancing,takeout,worldwide'),
#               ('user_id', 65068986),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 47)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1319065890038702082),
#               ('content', 'CR7 no tiene covid al covid le dio CR7'),
#               ('tags', None),
#               ('user_id', 1170777245771808768),
#               ('created_at', datetime.datetime(2020, 10, 21, 23, 59, 49)),
#               ('sentiment_neg', 0.216),
#               ('sentiment_neu', 0.784),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.296),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1320153014263554051),
#               ('content',
#                'Has Covid killed off the flu? https://t.co/8KtqWe2JQr'),
#               ('tags', None),
#               ('user_id', 931139978368872451),
#               ('created_at', datetime.datetime(2020, 10, 24, 23, 59, 40)),
#               ('sentiment_neg', 0.587),
#               ('sentiment_neu', 0.413),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.7964),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
# ...
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051600093646848),
#               ('content',
#                'Visit our website for the latest updates, resources, and support  is providing during this time of social distancing and Covid-19. https://t.co/kfyr8bixOF. We are here for you! #washyourhands… https://t.co/1pzra3jxiD'),
#               ('tags', 'washyourhands'),
#               ('user_id', 719883673273769985),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 49)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 0.9),
#               ('sentiment_pos', 0.1),
#               ('sentiment_compound', 0.4574),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051608364867592),
#               ('content',
#                '🛑 #URGENTE Anunciarán primer fallecido por Covid 19 en Uruguay👇'),
#               ('tags', 'URGENTE'),
#               ('user_id', 1915937186),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 51)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 1),
#               ('favorite_count', 2),
#               ('reply_count', 1),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051597014990852),
#               ('content',
#                'Los pacientes de Covid-19 en la Asamblea, es por culpa de los grupos económicos, diría ZOOlay'),
#               ('tags', None),
#               ('user_id', 110517382),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 48)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051595349962752),
#               ('content',
#                'El Gobierno obliga a quedarse en casa a los trabajadores de servicios no esenciales del 30 de marzo al 9 de abril. #Covid_19  https://t.co/dyneKt2wGY'),
#               ('tags', 'Covid_19'),
#               ('user_id', 840620286546440192),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 48)),
#               ('sentiment_neg', 0.099),
#               ('sentiment_neu', 0.901),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.296),
#               ('retweet_count', 0),
#               ('favorite_count', 1),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051606905257985),
#               ('content',
#                'Los noticiarios y famosos matinales deben destinar espacio o secciones especiales con noticias positivas y alentadoras en torno al Covid. No sólo se puede mostrar tensión o crisis ! Equilibrio #COVIDー19Chile'),
#               ('tags', 'COVIDー19Chile'),
#               ('user_id', 119518303),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 51)),
#               ('sentiment_neg', 0.215),
#               ('sentiment_neu', 0.785),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.7644),
#               ('retweet_count', 0),
#               ('favorite_count', 1),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051612412280832),
#               ('content',
#                'I hope that everyone clapping on their balconies for health care workers remembers to vote for increasing taxes to pay for properly funded health care services #Covid_19 #covid19Canada #CoronaLockdown'),
#               ('tags', 'Covid_19,covid19Canada,CoronaLockdown'),
#               ('user_id', 77754127),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 52)),
#               ('sentiment_neg', 0.04),
#               ('sentiment_neu', 0.692),
#               ('sentiment_pos', 0.268),
#               ('sentiment_compound', 0.836),
#               ('retweet_count', 0),
#               ('favorite_count', 1),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051612001239040),
#               ('content',
#                'How to reduce your risk of getting sick from Covid 19.'),
#               ('tags', None),
#               ('user_id', 31308870),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 52)),
#               ('sentiment_neg', 0.375),
#               ('sentiment_neu', 0.625),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.6597),
#               ('retweet_count', 0),
#               ('favorite_count', 1),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1246950697427521537),
#               ('content',
#                '#SuenaAhora Ion Band - Self #TalentoIndependiente  #QuedateEnCasa #Covid_19'),
#               ('tags',
#                'SuenaAhora,TalentoIndependiente,QuedateEnCasa,Covid_19'),
#               ('user_id', 403453681),
#               ('created_at', datetime.datetime(2020, 4, 5, 23, 59, 48)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051603302125568),
#               ('content', '#COVID1989GF #COVID19Aus #Covid_19 #CCPVirus'),
#               ('tags', 'COVID1989GF,COVID19Aus,Covid_19,CCPVirus'),
#               ('user_id', 23937693),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 50)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051602350264325),
#               ('content',
#                'Brasil tem 3.904 casos e 114 mortes por covid-19 https://t.co/JwViVwglY5 via '),
#               ('tags', None),
#               ('user_id', 2188416542),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 50)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 1),
#               ('favorite_count', 2),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051604397084673),
#               ('content',
#                '1h du matin un samedi soir .. je vais déjà me couché \nbatard de covid-19'),
#               ('tags', None),
#               ('user_id', 201701976),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 50)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 1),
#               ('favorite_count', 1),
#               ('reply_count', 2),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051603453140994),
#               ('content',
#                'Commented on Brick And Mortar Retail: Trying To Stay Alive Despite The (Not Only COVID-19) Virus. https://t.co/rgCYz63XpT'),
#               ('tags', None),
#               ('user_id', 1209952412338991104),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 50)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 0.86),
#               ('sentiment_pos', 0.14),
#               ('sentiment_compound', 0.3818),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051599598784513),
#               ('content',
#                "#selfisolation champions 6 FORK HANDS #staysafe #washyourhands and take care of yourself and your loved ones! Let's try to laugh through this! \n\n #COVIDCanada #COVIDIOT #COVIDIOTS #covid19Canada #covid19 #Covid_19 #corona #virus #comedy #Covid19OnlineComedyFest https://t.co/Z0KGJpUBFF"),
#               ('tags',
#                'selfisolation,staysafe,washyourhands,COVIDCanada,COVIDIOT,COVIDIOTS,covid19Canada,covid19,Covid_19,corona,virus,comedy,Covid19OnlineComedyFest'),
#               ('user_id', 3060261383),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 49)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 0.656),
#               ('sentiment_pos', 0.344),
#               ('sentiment_compound', 0.9401),
#               ('retweet_count', 0),
#               ('favorite_count', 3),
#               ('reply_count', 2),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051601087705088),
#               ('content',
#                '#NacionalesEC | En Venezuela hay 119 infectados con Covid-19\n.\n\nDelcy Rodríguez anunció seis nuevos casos de coronavirus confirmados en el país, cuatro de ellos son personas que regresaron del extranjero… https://t.co/NucEguxstu'),
#               ('tags', 'NacionalesEC'),
#               ('user_id', 1126857573431431169),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 49)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 1),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051609107267588),
#               ('content',
#                'EEUU: Autoridades confirmaron que ya son más de 2.000 los muertos por COVID-19 - AlbertoNews - Periodismo sin censura https://t.co/hbksditEuX'),
#               ('tags', None),
#               ('user_id', 441100686),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 51)),
#               ('sentiment_neg', 0.175),
#               ('sentiment_neu', 0.825),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', -0.5574),
#               ('retweet_count', 0),
#               ('favorite_count', 0),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051612395622402),
#               ('content', 'day 12 Covid quarantine: Owl City discography'),
#               ('tags', None),
#               ('user_id', 20913741),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 52)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 8),
#               ('reply_count', 1),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051605214896131),
#               ('content', 'تلبيس Covid-19 ما ليس فيه https://t.co/g6C0FmaLaF'),
#               ('tags', None),
#               ('user_id', 259162548),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 50)),
#               ('sentiment_neg', 0.0),
#               ('sentiment_neu', 1.0),
#               ('sentiment_pos', 0.0),
#               ('sentiment_compound', 0.0),
#               ('retweet_count', 0),
#               ('favorite_count', 1),
#               ('reply_count', 0),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  RealDictRow([('id', 1244051601964310529),
#               ('content',
#                "Turning 40 this weekend and I don't even care about celebrating. I want my friends and family to be there for my 41st, 42nd and all the rest of them. I'm staying in because of them. #covid_19 #coronavirus"),
#               ('tags', 'covid_19,coronavirus'),
#               ('user_id', 1046679758),
#               ('created_at', datetime.datetime(2020, 3, 28, 23, 59, 49)),
#               ('sentiment_neg', 0.062),
#               ('sentiment_neu', 0.749),
#               ('sentiment_pos', 0.19),
#               ('sentiment_compound', 0.6675),
#               ('retweet_count', 0),
#               ('favorite_count', 4),
#               ('reply_count', 1),
#               ('quote_count', 0),
#               ('reply_to', None),
#               ('fetched_comments', None),
#               ('type', 1),
#               ('fetched_retweets', None),
#               ('fetched_quotes', True)]),
#  ...]
